# %% [markdown]
# #### 背景说明
#
# 每年高考高后都会有很多学生和家长为报专业而犯难，本次项目以全国各高校的信息以及专业开设信息进行分析，为考生志愿填报提供帮助。
#
# #### 示例数据
# 项目数据为专业（professional）和学校（school）两份csv数据。</br>
# * school：
#
# | 字段      | 说明                                 |
# | -------- | ---------------------------------------- |
# | 学校    | 学校名称|
# | 省份 | 省份，包含直辖市                             |
# | 城市    | 地级市，不包含直辖市的区                                     |
# | 地址  | 学校地址 |
# | 水平层次  | 专科（高职）和普通本科 |
# | 办学类别  | 学校类型，比如理工类，综合类，财经类，师范类，医药类等 |
# | 办学类型  | 公办、民办或中外合资 |
# | 985  | 是否为985院校 |
# | 211  | 是否为211院校 |
# | 双一流  | 是否为双一流院校 |
# | 归属  | 隶属于哪个部门 |
# | 开设专业链接  | 专业介绍的网页链接 |
#
#
# ![image-2.png](attachment:image-2.png)
#
# * professional
#
# | 字段      | 说明                                 |
# | -------- | ---------------------------------------- |
# | 学校    | 学校名称|
# | 专业类别 | 专业所属类别                             |
# | 专业名称    | 专业的全称，包含定向类专业                                     |
# | 国家特色专业  | 是否为国家特色专业 |
#
# ![image-3.png](attachment:image-3.png)
#
# #### 分析思路
# 1.分析现有学校专业建设情况。由于专业名称中含有定向专业的名称需要去除，如：铁道交通运营管理（铁道旅客运输），另外还有一些无关字符也都要剔除。对清洗完的专业名称进行计数，可视化热度最高的专业。<br>
# 2.分析各省(市)高等教育水平实力分布。利用分组聚合的方式统计本科和专科学校的数量，然后用数据透视表功能做行列转换，并依此做堆积柱状图。<br>
# 3.分析湖北省双一流高校。展示出现频率较高的词汇。将professional和school两张表格按列拼接，筛选出湖北省内的双一流高校。然后对湖北双一流高校分别统计专业数量和特色专业数量，并绘制环形图进行对比分析。<br>
# 4.院校区域分析。利用分组聚合的方式统计各地级市的高校数量，利用pyecharts库进行地图可视化。<br>
# 5.分析北京市公办大学中专业名称包含“通信工程”的专业。基于共同列拼接professional和school两张表，按照“北京市”和“公办大学”筛选学校，最后在专业中筛选出含有“通信工程”的专业。

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
from pyecharts import options as opts
from pyecharts.charts import Map
import re

# %% [markdown]
# 考点一：读取csv文件，设置编码方式

# %%
# 读取编码为gbk，名为professional的csv文件
df_pro = pd.read_csv('professional.csv',encoding='gbk')
df_pro.head()
# Out:
#              学校        专业类别      专业名称 国家特色专业
# 0  河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN
# 1  河北轨道运输职业技术学院    土建施工类(专)    建筑工程技术    NaN
# 2  河北轨道运输职业技术学院  机械设计制造类(专)      数控技术    NaN
# 3  河北轨道运输职业技术学院    机电设备类(专)    电梯工程技术    NaN
# 4  河北轨道运输职业技术学院     自动化类(专)   机电一体化技术    NaN

# %% [markdown]
# 考点一：读取csv文件，设置编码方式

# %%
# 读取编码为gbk，名为school的csv文件
df_sch = pd.read_csv('school.csv',encoding='gbk')
df_sch.head()
# Out:
#              学校   省份    城市                               地址    水平层次 办学类别 办学类型  \
# 0  河北轨道运输职业技术学院  河北省  石家庄市  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办
# 1          厦门大学  福建省   厦门市                福建省厦门市思明区思明南路422号    普通本科  综合类   公办
# 2          四川大学  四川省   成都市                  四川省成都市一环路南一段24号    普通本科  综合类   公办
# 3          武汉大学  湖北省   武汉市                 湖北省武汉市武昌区八一路299号    普通本科  综合类   公办
# 4          北京大学  北京市   北京市                     北京市海淀区颐和园路5号    普通本科  综合类   公办
#
#   985 211  双一流   归属                                        开设专业链接
# 0   否   否  NaN  河北省  https://gkcx.eol.cn/school/2858/professional
# 1   是   是    是  教育部   https://gkcx.eol.cn/school/102/professional
# 2   是   是    是  教育部    https://gkcx.eol.cn/school/99/professional
# 3   是   是    是  教育部    https://gkcx.eol.cn/school/42/professional
# 4   是   是    是  教育部    https://gkcx.eol.cn/school/31/professional

# %% [markdown]
# ## 1.分析现有学校专业建设情况
# 分析国内高校专业建设情况，统计热门专业TOP50。<br>
# 思路：由于专业名称中含有定向专业的名称需要去除，如：铁道交通运营管理（铁道旅客运输），另外还有一些无关字符也都要剔除。对清洗完的专业名称进行计数，可视化热度最高的专业。

# %% [markdown]
# 1)专业名称中括号部分为补充说明，如培养方式等信息，需要将此部分内容清洗删除，如"机电一体化技术（中外合作办学）"清洗后为"机电一体化技术"；</br>
# 2)注意中英文括号混用、多用等情况，需要去除这些括号等特殊符号；

# %% [markdown]
# 考点二：编译正则表达式替换函数，用于替换（剔除）括号中中英文等特殊符号

# %%
# 利用正则表达式去除括号及括号内的内容，并去除多余括号
# 正则替换函数
def sub(s):
    # 将字符替换为空
    x = re.sub(u"\（.*?\）|\(.*?\）|\（.*?\)|\(.*?\)|[()（）]", "", s) 
    return x

# %% [markdown]
# 考点三：调用正则替换函数，对专业名称进行清洗<br>

# %%
# 调用正则替换函数对“专业名称”进行清洗  
df_pro['专业名称_清洗'] = df_pro['专业名称'].apply(lambda x: sub(x))
df_pro.head()
# Out:
#              学校        专业类别      专业名称 国家特色专业   专业名称_清洗
# 0  河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN  测绘地理信息技术
# 1  河北轨道运输职业技术学院    土建施工类(专)    建筑工程技术    NaN    建筑工程技术
# 2  河北轨道运输职业技术学院  机械设计制造类(专)      数控技术    NaN      数控技术
# 3  河北轨道运输职业技术学院    机电设备类(专)    电梯工程技术    NaN    电梯工程技术
# 4  河北轨道运输职业技术学院     自动化类(专)   机电一体化技术    NaN   机电一体化技术

# %% [markdown]
# 考点四：对清洗后的专业名称进行计数统计，并将数据类型转换为dataframe

# %%
# 对“专业名称_清洗”列中不同专业的数量进行计数，并转化为dataframe
df1 = df_pro['专业名称_清洗'].value_counts().to_frame()
# 只选取前50个数据展示
df1 = df1.iloc[:50,:] # 取前50行数据
df1

# 示例数据
# 专业名称_清洗  计数
# 市场营销      1426
# Out:
#              专业名称_清洗
# 市场营销            1426
# 电子商务            1352
# 旅游管理            1204
# 物流管理            1146
# 财务管理            1019
# 会计              1013
# 计算机科学与技术        1000
# 英语               999
# 国际经济与贸易          878
# 工程造价             851
# 学前教育             803
# 商务英语             734
# 会计学              729
# 酒店管理             728
# 计算机应用技术          725
# 视觉传达设计           712
# 环境设计             695
# 机电一体化技术          693
# 计算机网络技术          660
# 汉语言文学            657
# 电子信息工程           647
# 软件工程             613
# 法学               608
# 建筑工程技术           607
# 电气工程及其自动化        605
# 音乐表演             599
# 土木工程             580
# 机械设计制造及其自动化      576
# 软件技术             571
# 人力资源管理           570
# 工商管理             569
# 数据科学与大数据技术       538
# 数学与应用数学          531
# 通信工程             527
# 汽车检测与维修技术        523
# 音乐学              512
# 电气自动化技术          512
# 护理               490
# 物联网工程            480
# 自动化              463
# 日语               457
# 信息管理与信息系统        450
# 金融学              445
# 药学               442
# 小学教育             435
# 工业机器人技术          430
# 体育教育             426
# 产品设计             421
# 数控技术             413
# 工程管理             400

# %% [markdown]
# 考点五：绘制横置条形图

# %%
# 条形图展示各专业开设情况
# 设置图像大小（10,10）
plt.figure(figsize=(10,10))
# 横置条形图
plt.barh(df1.index,df1['专业名称_清洗'],color='c')
# 设置x轴标签
plt.xlabel('数量')
# 设置y轴标签
plt.ylabel('专业名称')
# 刻度标签
plt.xticks()
plt.show()

# %% [markdown]
# ## 2.分析各省(市)高等教育水平实力分布
# 分析比较各省（市）本科和专科学校的数量以及学校总数，利用堆积柱状图进行可视化比较分析。

# %% [markdown]
# 思路：利用分组聚合的方式统计本科和专科学校的数量，然后用数据透视表功能做行列转换，并依此做堆积柱状图。<br>

# %% [markdown]
# 考点六：对省份和水平层次进行分组聚合，计算各省份不同层次办学数量。

# %%
# 按照“省份”和“水平层次”进行分组聚合，统计每个省市本科和专科学校的数量，重设索引，做数据透视表
df2 = df_sch.groupby([df_sch['省份'],df_sch['水平层次']])['学校'].count().reset_index().pivot(index='省份',columns="水平层次",values='学校')
df2

# 示例
# 水平层次	专科（高职）	普通本科
# 省份		
# 上海市	21.0	44.0
# Out:
# 水平层次      专科（高职）  普通本科
# 省份
# 上海市         21.0  44.0
# 云南省         50.0  32.0
# 内蒙古自治区      37.0  19.0
# 北京市         25.0  77.0
# 吉林省         30.0  40.0
# 四川省         82.0  55.0
# 天津市         26.0  36.0
# 宁夏回族自治区     12.0   8.0
# 安徽省         76.0  52.0
# 山东省         86.0  74.0
# 山西省         50.0  35.0
# 广东省         93.0  70.0
# 广西壮族自治区     49.0  36.0
# 新疆维吾尔自治区    36.0  20.0
# 江苏省         89.0  85.0
# 江西省         61.0  47.0
# 河北省         65.0  61.0
# 河南省         99.0  59.0
# 浙江省         50.0  61.0
# 海南省         13.0   8.0
# 湖北省         62.0  72.0
# 湖南省         77.0  52.0
# 澳门特别行政区      NaN   5.0
# 甘肃省         30.0  22.0
# 福建省         49.0  41.0
# 西藏自治区        3.0   3.0
# 贵州省         47.0  30.0
# 辽宁省         48.0  62.0
# 重庆市         43.0  30.0
# 陕西省         41.0  63.0
# 青海省          8.0   4.0
# 香港特别行政区      NaN  14.0
# 黑龙江省        41.0  40.0

# %% [markdown]
# 考点七：调整为行索引为单层索引

# %%
# 调整行索引为单层索引，“水平层次”调整为列索引
df2.reset_index(inplace=True)
df2
# Out:
# 水平层次        省份  专科（高职）  普通本科
# 0          上海市    21.0  44.0
# 1          云南省    50.0  32.0
# 2       内蒙古自治区    37.0  19.0
# 3          北京市    25.0  77.0
# 4          吉林省    30.0  40.0
# 5          四川省    82.0  55.0
# 6          天津市    26.0  36.0
# 7      宁夏回族自治区    12.0   8.0
# 8          安徽省    76.0  52.0
# 9          山东省    86.0  74.0
# 10         山西省    50.0  35.0
# 11         广东省    93.0  70.0
# 12     广西壮族自治区    49.0  36.0
# 13    新疆维吾尔自治区    36.0  20.0
# 14         江苏省    89.0  85.0
# 15         江西省    61.0  47.0
# 16         河北省    65.0  61.0
# 17         河南省    99.0  59.0
# 18         浙江省    50.0  61.0
# 19         海南省    13.0   8.0
# 20         湖北省    62.0  72.0
# 21         湖南省    77.0  52.0
# 22     澳门特别行政区     NaN   5.0
# 23         甘肃省    30.0  22.0
# 24         福建省    49.0  41.0
# 25       西藏自治区     3.0   3.0
# 26         贵州省    47.0  30.0
# 27         辽宁省    48.0  62.0
# 28         重庆市    43.0  30.0
# 29         陕西省    41.0  63.0
# 30         青海省     8.0   4.0
# 31     香港特别行政区     NaN  14.0
# 32        黑龙江省    41.0  40.0

# %% [markdown]
# 考点八：绘制堆叠柱状图，刻度标签倾斜60度

# %%
# 绘制各省份学校层次情况堆积柱状图

# 设置图像大小为（10,10）
plt.figure(figsize=(10,10))
# 柱状图。“普通本科”柱状图，设置横轴标签为“省份”
plt.bar(df2['省份'], df2['普通本科'], align='center', color='#66c2a5', tick_label=df2['省份'], label='本科')
# 柱状图。“专科（高职）”柱状图，堆积在“普通本科”柱状图上
plt.bar(df2['省份'], df2['专科（高职）'],  bottom=df2['普通本科'], color='#8da0cb', label='专科')  
# 设置x轴标签
plt.xlabel('省份')
# 设置y轴标签
plt.ylabel('学校层次')
# 刻度标签倾斜60度
plt.xticks(rotation=60)
# 显示图例
plt.legend()  
plt.show()

# %% [markdown]
# ## 3.分析湖北省双一流高校
# 分析湖北的双一流高校，对各学校的专业和特色专业进行对比分析。<br>
# 思路：将professional和school两张表格按列拼接，筛选出湖北省内的双一流高校。然后对湖北双一流高校分别统计专业数量和特色专业数量，并绘制环形图进行对比分析。

# %% [markdown]
# 考点九：基于相同列进行数据合并

# %%
# 基于相同列拼接df_pro和df_sch
df3 = pd.merge(df_pro,df_sch)
df3.head()
# Out:
#              学校        专业类别      专业名称 国家特色专业   专业名称_清洗   省份    城市  \
# 0  河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN  测绘地理信息技术  河北省  石家庄市
# 1  河北轨道运输职业技术学院    土建施工类(专)    建筑工程技术    NaN    建筑工程技术  河北省  石家庄市
# 2  河北轨道运输职业技术学院  机械设计制造类(专)      数控技术    NaN      数控技术  河北省  石家庄市
# 3  河北轨道运输职业技术学院    机电设备类(专)    电梯工程技术    NaN    电梯工程技术  河北省  石家庄市
# 4  河北轨道运输职业技术学院     自动化类(专)   机电一体化技术    NaN   机电一体化技术  河北省  石家庄市
#
#                                 地址    水平层次 办学类别 办学类型 985 211  双一流   归属  \
# 0  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 1  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 2  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 3  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 4  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
#
#                                          开设专业链接
# 0  https://gkcx.eol.cn/school/2858/professional
# 1  https://gkcx.eol.cn/school/2858/professional
# 2  https://gkcx.eol.cn/school/2858/professional
# 3  https://gkcx.eol.cn/school/2858/professional
# 4  https://gkcx.eol.cn/school/2858/professional

# %% [markdown]
# 考点十：按要求筛选出湖北省双一流建设名单并输出学校名称

# %%
# 筛选出“湖北省”的“双一流”的大学
df_hubei= df3[(df3['省份']=='湖北省')&(df3['双一流']=='是')]
df_hubei.head()
# Out:
#        学校     专业类别 专业名称 国家特色专业 专业名称_清洗   省份   城市                地址  水平层次 办学类别  \
# 251  武汉大学   哲学类(本)   哲学      是      哲学  湖北省  武汉市  湖北省武汉市武昌区八一路299号  普通本科  综合类
# 252  武汉大学   哲学类(本)  宗教学    NaN     宗教学  湖北省  武汉市  湖北省武汉市武昌区八一路299号  普通本科  综合类
# 253  武汉大学  经济学类(本)  经济学      是     经济学  湖北省  武汉市  湖北省武汉市武昌区八一路299号  普通本科  综合类
# 254  武汉大学  财政学类(本)  财政学    NaN     财政学  湖北省  武汉市  湖北省武汉市武昌区八一路299号  普通本科  综合类
# 255  武汉大学  金融学类(本)  金融学    NaN     金融学  湖北省  武汉市  湖北省武汉市武昌区八一路299号  普通本科  综合类
#
#     办学类型 985 211 双一流   归属                                      开设专业链接
# 251   公办   是   是   是  教育部  https://gkcx.eol.cn/school/42/professional
# 252   公办   是   是   是  教育部  https://gkcx.eol.cn/school/42/professional
# 253   公办   是   是   是  教育部  https://gkcx.eol.cn/school/42/professional
# 254   公办   是   是   是  教育部  https://gkcx.eol.cn/school/42/professional
# 255   公办   是   是   是  教育部  https://gkcx.eol.cn/school/42/professional

# %%
df_hubei['学校'].unique()
# Out:
# array(['武汉大学', '华中科技大学', '武汉理工大学', '中南财经政法大学', '华中师范大学', '中国地质大学（武汉）',
#        '华中农业大学'], dtype=object)

# %% [markdown]
# ## 4.院校区域分析
# 按照“地级市”进行的高校分布解读，统计各省份学校数量，使用中国地图进行可视化展示。<br>
# 思路：利用分组聚合的方式统计各地级市的高校数量，利用pyecharts库进行地图可视化。

# %% [markdown]
# 考点十一：借助地图对院校进行区域数据可视化

# %%
# 按“城市”进行分组聚合，统计“学校”的数量
df4 = df_sch.groupby([df_sch['城市']])['学校'].count()
# “学校”数量降序排列
df4.sort_values(ascending=False)
# Out:
# 城市
# 北京市       102
# 武汉市        87
# 广州市        85
# 重庆市        73
# 郑州市        70
#          ...
# 定西市         1
# 锡林郭勒盟       1
# 大兴安岭地区      1
# 塔城地区        1
# 七台河市        1
# Name: 学校, Length: 329, dtype: int64

# %% [markdown]
# 考点十二：使用notebook网页形式进行渲染生成图形

# %%
# 取Series的索引和值，转换为list
attr = df4.index.tolist() # 索引
value = df4.values.tolist() # 值

c = (
    # 地理区域数据的可视化
    Map()
        # 设置图标题，省及对应数量，中国地级市地图，不显示标签
        .add(
            "各市学校分布", 
            [list(z) for z in zip(attr, value)], 
            "china-cities",
            label_opts=opts.LabelOpts(is_show=False),
            )
        # 全局配置，配置全局标题，视觉映射配置项
        .set_global_opts(
                        title_opts=opts.TitleOpts(title="各市学校分布"), 
                        visualmap_opts=opts.VisualMapOpts()
    )
      
)
# 渲染图片并显示
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china-cities':'https://assets.pyecharts.org/assets/v5/maps/china-cities'
#         }
#     });
# </script>
#
#         <div id="97386dd5157d410ea98654c222461be2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china-cities'], function(echarts) {
#                 var chart_97386dd5157d410ea98654c222461be2 = echarts.init(
#                     document.getElementById('97386dd5157d410ea98654c222461be2'), 'white', {renderer: 'canvas'});
#                 var option_97386dd5157d410ea98654c222461be2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5404\u5e02\u5b66\u6821\u5206\u5e03",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "map": "china-cities",
#             "data": [
#                 {
#                     "name": "\u4e03\u53f0\u6cb3\u5e02",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e09\u4e9a\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u4e09\u660e\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e09\u95e8\u5ce1\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u4e0a\u9976\u5e02",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u4e1c\u839e\u5e02",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u4e1c\u8425\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u4e2d\u5c71\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e34\u590f\u56de\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e34\u6c7e\u5e02",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u4e34\u6c82\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u4e34\u6ca7\u5e02",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e39\u4e1c\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e3d\u6c34\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e3d\u6c5f\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e4c\u5170\u5bdf\u5e03\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e4c\u6d77\u5e02",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50\u5e02",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u4e50\u5c71\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4e5d\u6c5f\u5e02",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u4e5d\u9f99\u534a\u5c9b",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u4e91\u6d6e\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4eb3\u5dde\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4f0a\u6625\u5e02",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4f0a\u7281\u54c8\u8428\u514b\u81ea\u6cbb\u5dde",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4f5b\u5c71\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u4f73\u6728\u65af\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u4fdd\u5b9a\u5e02",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u4fdd\u5c71\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4fe1\u9633\u5e02",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u514b\u5b5c\u52d2\u82cf\u67ef\u5c14\u514b\u5b5c\u81ea\u6cbb\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u514b\u62c9\u739b\u4f9d\u5e02",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u516d\u5b89\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u516d\u76d8\u6c34\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5170\u5dde\u5e02",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5174\u5b89\u76df",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5185\u6c5f\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u51c9\u5c71\u5f5d\u65cf\u81ea\u6cbb\u5dde",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5305\u5934\u5e02",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 102
#                 },
#                 {
#                     "name": "\u5317\u6d77\u5e02",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5341\u5830\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5357\u4eac\u5e02",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5357\u5145\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5357\u5b81\u5e02",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5357\u5e73\u5e02",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5357\u660c\u5e02",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u5357\u901a\u5e02",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5357\u9633\u5e02",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u535a\u5c14\u5854\u62c9\u8499\u53e4\u81ea\u6cbb\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u53a6\u95e8\u5e02",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u53cc\u9e2d\u5c71\u5e02",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u53f0\u5dde\u5e02",
#                     "value":

# %% [markdown]
# ## 5.分析北京市公办大学中专业名称包含“通信工程”的专业
# 现有学生，想报考北京公办大学中的"通信工程"专业。请根据要求进行分析，筛选出学生想要报考大学及专业的全部信息。<br>
# 思路：基于共同列拼接professional和school两张表，按照“北京市”和“公办大学”筛选学校，最后在专业中筛选出含有“通信工程”的专业。

# %%
# 基于相同列拼接df_pro和df_sch
df5 = pd.merge(df_pro,df_sch)
df5.head()
# Out:
#              学校        专业类别      专业名称 国家特色专业   专业名称_清洗   省份    城市  \
# 0  河北轨道运输职业技术学院  测绘地理信息类(专)  测绘地理信息技术    NaN  测绘地理信息技术  河北省  石家庄市
# 1  河北轨道运输职业技术学院    土建施工类(专)    建筑工程技术    NaN    建筑工程技术  河北省  石家庄市
# 2  河北轨道运输职业技术学院  机械设计制造类(专)      数控技术    NaN      数控技术  河北省  石家庄市
# 3  河北轨道运输职业技术学院    机电设备类(专)    电梯工程技术    NaN    电梯工程技术  河北省  石家庄市
# 4  河北轨道运输职业技术学院     自动化类(专)   机电一体化技术    NaN   机电一体化技术  河北省  石家庄市
#
#                                 地址    水平层次 办学类别 办学类型 985 211  双一流   归属  \
# 0  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 1  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 2  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 3  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
# 4  河北省石家庄市经济技术开发区赣江路9号,石家庄市宁安路189号  专科（高职）  理工类   公办   否   否  NaN  河北省
#
#                                          开设专业链接
# 0  https://gkcx.eol.cn/school/2858/professional
# 1  https://gkcx.eol.cn/school/2858/professional
# 2  https://gkcx.eol.cn/school/2858/professional
# 3  https://gkcx.eol.cn/school/2858/professional
# 4  https://gkcx.eol.cn/school/2858/professional

# %%
# 筛选“城市”为“北京”且“办学类型”是“公办”的大学
df_bj = df5[(df5['城市']=='北京市')&(df5['办学类型']=='公办')]
df_bj.head()
# Out:
#        学校     专业类别      专业名称 国家特色专业   专业名称_清洗   省份   城市            地址  水平层次  \
# 377  北京大学   哲学类(本)        哲学      是        哲学  北京市  北京市  北京市海淀区颐和园路5号  普通本科
# 378  北京大学   哲学类(本)       宗教学    NaN       宗教学  北京市  北京市  北京市海淀区颐和园路5号  普通本科
# 379  北京大学   哲学类(本)       逻辑学    NaN       逻辑学  北京市  北京市  北京市海淀区颐和园路5号  普通本科
# 380  北京大学  经济学类(本)       经济学      是       经济学  北京市  北京市  北京市海淀区颐和园路5号  普通本科
# 381  北京大学  经济学类(本)  资源与环境经济学    NaN  资源与环境经济学  北京市  北京市  北京市海淀区颐和园路5号  普通本科
#
#     办学类别 办学类型 985 211 双一流   归属                                      开设专业链接
# 377  综合类   公办   是   是   是  教育部  https://gkcx.eol.cn/school/31/professional
# 378  综合类   公办   是   是   是  教育部  https://gkcx.eol.cn/school/31/professional
# 379  综合类   公办   是   是   是  教育部  https://gkcx.eol.cn/school/31/professional
# 380  综合类   公办   是   是   是  教育部  https://gkcx.eol.cn/school/31/professional
# 381  综合类   公办   是   是   是  教育部  https://gkcx.eol.cn/school/31/professional

# %% [markdown]
# 考点十三：检查数据是否包含某一字符串

# %%
# 在上一步基础上，将“专业名称_清洗”列转换为字符串，判断是否包含和“通信工程”
df_bj[df_bj['专业名称_清洗'].str.contains('通信工程')]
# Out:
#              学校      专业类别               专业名称 国家特色专业 专业名称_清洗   省份   城市  \
# 1524     北京邮电大学  电子信息类(本)               通信工程      是    通信工程  北京市  北京市
# 5752   北京航空航天大学  电子信息类(本)               通信工程      是    通信工程  北京市  北京市
# 7144     中国传媒大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 7147     中国传媒大学  电子信息类(本)  通信工程（无线多媒体广播技术方向）    NaN    通信工程  北京市  北京市
# 7847     北京工业大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 8971     北京交通大学  电子信息类(本)               通信工程      是    通信工程  北京市  北京市
# 9365     华北电力大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 10828    中国农业大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 10894    北京科技大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 13272    北京联合大学  电子信息类(本)               通信工程      是    通信工程  北京市  北京市
# 15220    中央民族大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 19068    北京化工大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 26030    北方工业大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 27721  北京信息科技大学  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 28177  北京电子科技学院  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
# 30453  北京石油化工学院  电子信息类(本)               通信工程    NaN    通信工程  北京市  北京市
#
#                                             地址  水平层次 办学类别 办学类型 985 211  双一流  \
# 1524                                北京市西土城路10号  普通本科  理工类   公办   否   是    是
# 5752      学院路校区：北京市海淀区学院路37号;沙河校区：北京市昌平区沙河高教园区  普通本科  理工类   公办   是   是    是
# 7144                             北京市朝阳区定福庄东街一号  普通本科  艺术类   公办   否   是    是
# 7147                             北京市朝阳区定福庄东街一号  普通本科  艺术类   公办   否   是    是
# 7847   平乐园校区：北京市朝阳区平乐园100号,通州校区：北京市通州区潞苑南大街89号  普通本科  理工类   公办   否   是    是
# 8971                           北京市海淀区西直门外上园村3号  普通本科  理工类   公办   否   是    是
# 9365                            北京市昌平区回龙观北农路2号  普通本科  理工类   公办   否   是    是
# 10828                            北京市海淀区清华东路17号  普通本科  农林类   公办   是   是    是
# 10894                             北京市海淀区学院路30号  普通本科  理工类   公办   否   是    是
# 13272                           北京市朝阳区北四环东路97号  普通本科  综合类   公办   否   否  NaN
# 15220                          北京市海淀区中关村南大街27号  普通本科  民族类   公办   是   是    是
# 19068                           北京市朝阳区北三环东路15号  普通本科  理工类   公办   否   是    是
# 26030                            北京市石景山区晋元庄路5号  普通本科  理工类   公办   否   否  NaN
# 27721                          北京市海淀区清河小营东路12号  普通本科  理工类   公办   否   否  NaN
# 28177                              北京市丰台区富丰路7号  普通本科  理工类   公办   否   否  NaN
# 30453                         北京市大兴区黄村镇清源北路19号  普通本科  综合类   公办   否   否  NaN
#
#             归属                                       开设专业链接
# 1524       教育部   https://gkcx.eol.cn/school/48/professional
# 5752   工业和信息化部   https://gkcx.eol.cn/school/47/professional
# 7144       教育部  https://gkcx.eol.cn/school/558/professional
# 7147       教育部  https://gkcx.eol.cn/school/558/professional
# 7847       北京市   https://gkcx.eol.cn/school/30/professional
# 8971       教育部   https://gkcx.eol.cn/school/38/professional
# 9365       教育部  https://gkcx.eol.cn/school/831/professional
# 10828      教育部  https://gkcx.eol.cn/school/557/professional
# 10894      教育部  https://gkcx.eol.cn/school/144/professional
# 13272      北京市  https://gkcx.eol.cn/school/575/professional
# 15220     国家民委   https://gkcx.eol.cn/school/45/professional
# 19068      教育部  https://gkcx.eol.cn/school/556/professional
# 26030      北京市  https://gkcx.eol.cn/school/561/professional
# 27721      北京市  https://gkcx.eol.cn/school/879/professional
# 28177    中央办公厅  https://gkcx.eol.cn/school/565/professional
# 30453      北京市  https://gkcx.eol.cn/school/580/professional
